# %%
import pandas as pd
import numpy as np
heart_disease=pd.read_csv("11.2 heart-disease.csv")
heart_disease
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
np.random.seed(42)
X=heart_disease.drop("target",axis=1)
Y=heart_disease["target"]
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2)
clf=RandomForestClassifier(n_estimators=100)
clf.fit(X_train,Y_train)
#Make some predictions
y_preds=clf.predict(X_test)
print("classifier evalution metrics:")
print(f"Accuracy:{accuracy_score(Y_test,y_preds)*100:.2f}%")
print(f"Precision:{precision_score(Y_test,y_preds)}")
print(f"Recall_Score:{recall_score(Y_test,y_preds)}")
print(f"F1_Score:{f1_score(Y_test,y_preds)}")
# Out:
# classifier evalution metrics:
# Accuracy:85.25%
# Precision:0.8484848484848485
# Recall_Score:0.875
# F1_Score:0.8615384615384616

# %%
#Regression Evalution functions

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
np.random.seed(42)
X=heart_disease.drop("target",axis=1)
Y=heart_disease["target"]
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2)
model=RandomForestClassifier(n_estimators=100)
model.fit(X_train,Y_train)
#Make some predictions
y_preds=model.predict(X_test)
print("Regression evalution functions")
print(f"R^2 :{r2_score(Y_test,y_preds)}")
print(f"MAE :{mean_absolute_error(Y_test,y_preds)}")
print(f"MSE :{mean_squared_error(Y_test,y_preds)}")
# Out:
# Regression evalution functions
# R^2 :0.40840517241379315
# MAE :0.14754098360655737
# MSE :0.14754098360655737

# %% [markdown]
# #improving the model
# clf.get_params()

# %%
#tuning hyper parameters
from sklearn.model_selection import RandomizedSearchCV
grid={"n_estimators":[100,200,300,400,500,600],
      "max_depth":[None,3,4,5],
      "max_features":["auto","sqrt"],
     "min_samples_split":[2,4,6],
      "min_samples_leaf":[1,2,3]
     }
np.random.seed(42)
heart_disease_shuffled=heart_disease.sample(frac=1)
X=heart_disease_shuffled.drop("target",axis=1)
Y=heart_disease_shuffled["target"]
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2)
clf=RandomForestClassifier(n_jobs=1)
rs_clf=RandomizedSearchCV(estimator=clf,param_distributions=grid,n_iter=10,cv=5,verbose=2)
rs_clf.fit(X_train,Y_train);
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END max_depth=4, max_features=auto, min_samples_leaf=3, min_samples_split=4, n_estimators=300; total time=   0.0s
# [CV] END max_depth=4, max_features=auto, min_samples_leaf=3, min_samples_split=4, n_estimators=300; total time=   0.0s
# [CV] END max_depth=4, max_features=auto, min_samples_leaf=3, min_samples_split=4, n_estimators=300; total time=   0.0s
# [CV] END max_depth=4, max_features=auto, min_samples_leaf=3, min_samples_split=4, n_estimators=300; total time=   0.0s
# [CV] END max_depth=4, max_features=auto, min_samples_leaf=3, min_samples_split=4, n_estimators=300; total time=   0.0s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=3, min_samples_split=6, n_estimators=500; total time=   2.9s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=3, min_samples_split=6, n_estimators=500; total time=   3.2s
# ...

# %%
rs_clf.best_params_
# Out:
# {'n_estimators': 500,
#  'min_samples_split': 2,
#  'min_samples_leaf': 2,
#  'max_features': 'sqrt',
#  'max_depth': 3}

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

def evaluate_preds(y_true, y_preds):
    """
    Evaluates the model's predictions using common classification metrics.
    
    Parameters:
    - y_true: The true labels.
    - y_preds: The predicted labels.

    Returns:
    A dictionary of the evaluation metrics.
    """
    accuracy = accuracy_score(y_true, y_preds)
    precision = precision_score(y_true, y_preds)
    recall = recall_score(y_true, y_preds)
    f1 = f1_score(y_true, y_preds)

    print(f"Accuracy: {accuracy * 100:.2f}%")
    print(f"Precision: {precision:.2f}")
    print(f"Recall: {recall:.2f}")
    print(f"F1 Score: {f1:.2f}")
    
    return {"accuracy": accuracy, "precision": precision, "recall": recall, "f1": f1}

# %%
rs_y_preds=rs_clf.predict(X_test)
rs_metrics=evaluate_preds(Y_test,rs_y_preds)
# Out:
# Accuracy: 83.61%
# Precision: 0.85
# Recall: 0.85
# F1 Score: 0.85

# %%
#hyper parameter tuning using gridSearchCV
grid
# Out:
# {'n_estimators': [100, 200, 300, 400, 500, 600],
#  'max_depth': [None, 3, 4, 5],
#  'max_features': ['auto', 'sqrt'],
#  'min_samples_split': [2, 4, 6],
#  'min_samples_leaf': [1, 2, 3]}

# %%
grid_1={'n_estimators': [100, 200, 300, 400],
 'max_depth': [None],
 'max_features': ['auto', 'sqrt'],
 'min_samples_split': [2, 6],
 'min_samples_leaf': [1]}
from sklearn.model_selection import GridSearchCV
np.random.seed(42)
heart_disease_shuffled=heart_disease.sample(frac=1)
X=heart_disease_shuffled.drop("target",axis=1)
Y=heart_disease_shuffled["target"]
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2)
clf=RandomForestClassifier(n_jobs=1)
gs_clf=RandomizedSearchCV(estimator=clf,param_distributions=grid_1,cv=5,verbose=2)
gs_clf.fit(X_train,Y_train);
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=400; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=400; total time=   0.0s
# ...

# %%
gs_clf.best_params_
# Out:
# {'n_estimators': 200,
#  'min_samples_split': 6,
#  'min_samples_leaf': 1,
#  'max_features': 'sqrt',
#  'max_depth': None}

# %%
gs_clf_y_preds=gs_clf.predict(X_test)
gs_metrics=evaluate_preds(Y_test,gs_clf_y_preds)
# Out:
# Accuracy: 80.33%
# Precision: 0.84
# Recall: 0.79
# F1 Score: 0.81

# %%
##Saving and loading trained machine learning mdoel:
#Two ways of save and load are:
#1.with python's ''pickle'' module
#2.with joblib module

# %%
import pickle
pickle.dump(gs_clf,open("gs_random_forest.pkl","wb"))

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 8
#       4 import numpy as np
#       6 # Use the models and scaler we trained earlier
#       7 models = {
# ----> 8     "KNN": knn,
#       9     "Decision Tree": dt
#      10 }
#      11 scalers = scaler
#      13 # Feature names from dataset
#
# NameError: name 'knn' is not defined
